# %% [markdown]
# # ModernBERT v3 Training Pipeline
#
# This notebook runs the complete 4-phase training orchestrator for ModernBERT v3.
#
# **Phases:**
# - **Phase 0.5**: Enhanced Healing (knowledge preservation)
# - **Phase 1**: Multi-Task FamilyOS Training
# - **Phase 1.5**: Forgetting Gate Evaluation
# - **Phase 2**: Fine-Tuning (optional)

# %% [markdown]
# ## 1. Setup Environment

# %%
# Clone repository (skip if already cloned)
import os
if not os.path.exists("Modeling_studio"):
    # !git clone https://github.com/Pkansagra-hub/Family_osModernBERT.git Modeling_studio

# Change to project directory
# %cd Modeling_studio

# Install dependencies
# !pip install -q -e .
# !pip install -q transformers datasets wandb accelerate

# Verify GPU
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# d:\Modeling_studio\notebooks\Modeling_studio\Modeling_studio\Modeling_studio
# Cloning into 'Modeling_studio'...
# Updating files:  30% (195/630)
# Updating files:  31% (196/630)
# Updating files:  32% (202/630)
# Updating files:  33% (208/630)
# Updating files:  34% (215/630)
# Updating files:  35% (221/630)
# Updating files:  36% (227/630)
# Updating files:  37% (234/630)
# Updating files:  38% (240/630)
# Updating files:  39% (246/630)
# Updating files:  40% (252/630)
# Updating files:  41% (259/630)
# Updating files:  42% (265/630)
# Updating files:  43% (271/630)
# Updating files:  44% (278/630)
# Updating files:  45% (284/630)
# Updating files:  46% (290/630)
# Updating files:  47% (297/630)
# Updating files:  48% (303/630)
# Updating files:  49% (309/630)
# Updating files:  50% (315/630)
# Updating files:  51% (322/630)
# Updating files:  52% (328/630)
# Updating files:  53% (334/630)
# Updating files:  54% (341/630)
# Updating files:  55% (347/630)
# ...

# %% [markdown]
# ## 2. Run Training Pipeline
#
# ### Debug Run (quick test - 5 steps per phase)

# %%
# Debug run: 5 training steps, 500 samples per phase
# Using -u flag for unbuffered output (critical for Colab real-time logging)
# !python -u scripts/v3_scripts/train_v3_orchestrator.py \
    --start-phase 0.5 \
    --end-phase 2 \
    --output-dir outputs/v3_full \
    --debug-run
# Out:
# ...
# [PHASE 0.5] Output:
# ...
# 2025-12-08 00:52:27 - INFO - __main__ - Loaded config from configs\training\multitask\stage_v3_phase0_5_enhanced.yaml
#
# ...
# Phase 0.5 DEBUG Mode (5 steps, 500 samples)
# ...
# 2025-12-08 00:52:27 - DEBUG - urllib3.connectionpool - Starting new HTTPS connection (1): huggingface.co:443
# 2025-12-08 00:52:28 - DEBUG - urllib3.connectionpool - https://huggingface.co:443 "HEAD /answerdotai/ModernBERT-base/resolve/main/tokenizer_config.json HTTP/1.1" 307 0
# 2025-12-08 00:52:28 - DEBUG - urllib3.connectionpool - https://huggingface.co:443 "HEAD /api/resolve-cache/models/answerdotai/ModernBERT-base/8949b909ec900327062f0ebf497f51aef5e6f0c8/tokenizer_config.json HTTP/1.1" 200 0
# 2025-12-08 00:52:28 - DEBUG - urllib3.connectionpool - https://huggingface.co:443 "GET /api/models/answerdotai/ModernBERT-base/tree/main/additional_chat_templates?recursive=False&expand=False HTTP/1.1" 404 64
# ...

# %% [markdown]
# ### Full Training Run (production)

# %%
# Full training run (uncomment to run)
# !python -u scripts/v3_scripts/train_v3_orchestrator.py \
#     --start-phase 0.5 \
#     --end-phase 2 \
#     --output-dir outputs/v3_full
